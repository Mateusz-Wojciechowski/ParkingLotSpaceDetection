# %% [markdown]
# <a href="https://colab.research.google.com/github/Mateusz-Wojciechowski/ParkingLotSpaceDetection/blob/main/ParkingLotProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# !pip install roboflow

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.pt')

from roboflow import Roboflow
rf = Roboflow(api_key="uJ2SoglHrWOcosLLPKit")
project = rf.workspace("brad-dwyer").project("pklot-1tros")
dataset = project.version(4).download("yolov8")

# %%
dataset.location
# Out:
# '/content/PKLot-4'

# %%
results = model.train(data='/content/PKLot-4/data.yaml', epochs=5, imgsz=416)
# Out:
# Ultralytics YOLOv8.0.232 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model_trained = YOLO('/content/runs/detect/train2/weights/best.pt')
results_trained = model(source='/content/PKLot-4/valid/images/2012-09-11_15_36_32_jpg.rf.5d294269f5ef750dac32cebbe9645f6a.jpg', show=False, conf=0.4)
# Out:
# image 1/1 /content/PKLot-4/valid/images/2012-09-11_15_36_32_jpg.rf.5d294269f5ef750dac32cebbe9645f6a.jpg: 416x416 30 space-emptys, 74 space-occupieds, 13.1ms
# Speed: 1.0ms preprocess, 13.1ms inference, 3.9ms postprocess per image at shape (1, 3, 416, 416)

# %%
import glob
from IPython.display import Image, display
from PIL import Image

# %%
Image(filename='/content/runs/detect/train2/confusion_matrix.png', width=700)

# %%
Image(filename='/content/runs/detect/train2/results.png')
